# %%
import json
import requests
import pandas as pd
import numpy as np

# %%
url = "https://www.gridwhiz.io/evat/New.json"
  
response = requests.get(url,verify=False)
response.json()
# Out:
# c:\Users\PC\miniconda3\envs\EV\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.gridwhiz.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [{'Operator': 'Elex by EGAT',
#   'Station': 'ตึกผู้ว่าการฯ สำนักงานกลาง กฟผ.2 ท.100',
#   'Lattitude': 13.810481,
#   'Longitude': 100.506343,
#   'Charger': 1,
#   'CHAdeMO': 1,
#   'CSS2': 1,
#   'AC': 1},
#  {'Operator': 'Elex by EGAT',
#   'Station': 'ศูนย์การเรียนรู้ สนก.กฟผ.',
#   'Lattitude': 13.812466,
#   'Longitude': 100.511692,
#   'Charger': 1,
#   'CHAdeMO': None,
#   'CSS2': 1,
#   'AC': None},
#  {'Operator': 'Elex by EGAT',
#   'Station': 'หน้าร้านกาแฟคุณสายชล',
#   'Lattitude': 13.811783,
#   'Longitude': 100.505717,
#   'Charger': 3,
#   'CHAdeMO': None,
#   'CSS2': None,
#   'AC': 3},
#  {'Operator': 'Elex by EGAT',
# ...

# %%
df = pd.DataFrame(response.json())
df.to_csv('EVAT.csv',index=False,encoding="utf-8-sig")

# %% [markdown]
# # Upload data to DataPlatform

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_raw_id = 41
dir_process_id = 42

# %%
datanode = DataNode()

# %%
datanode.upload_file(directory_id=dir_raw_id, file_path='EVAT.csv')
